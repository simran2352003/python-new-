# %%
import pandas as pd

# %%
df = pd.DataFrame([12,34,55,11,10])

# %%
df
# Out:
#     0
# 0  12
# 1  34
# 2  55
# 3  11
# 4  10

# %%
df1 = pd.DataFrame ({'Name':['sourav','priya','simran']})

# %%
df1
# Out:
#      Name
# 0  sourav
# 1   priya
# 2  simran

# %%
df1.head()
# Out:
#      Name
# 0  sourav
# 1   priya
# 2  simran

# %%
df1
# Out:
#      Name
# 0  sourav
# 1   priya
# 2  simran

# %%
df1.tail()
# Out:
#      Name
# 0  sourav
# 1   priya
# 2  simran

# %%
#access
df1['Name']
df1.Name[:3]
# Out:
# 0    sourav
# 1     priya
# 2    simran
# Name: Name, dtype: str

# %%
df.loc[:'class']
# Out:
#     0
# 0  12
# 1  34
# 2  55
# 3  11
# 4  10

# %%
df1
# Out:
#      Name
# 0  sourav
# 1   priya
# 2  simran
