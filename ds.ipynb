# %%
import pandas as pd

# %%
df = pd.read_excel('neet_data.xlsx')

# %%
df
# Out:
#                 created_at  retweet_count               source  \
# 0      2020-10-31 14:10:28            141  Twitter for Android
# 1      2020-10-31 14:10:11              1   Twitter for iPhone
# 2      2020-10-31 14:09:48            141      Twitter Web App
# 3      2020-10-31 14:09:41            141  Twitter for Android
# 4      2020-10-31 14:09:22              0  Twitter for Android
# ...                    ...            ...                  ...
# 47376  2020-10-30 15:29:35              0  Twitter for Android
# 47377  2020-10-30 15:29:35           1700  Twitter for Android
# 47378  2020-10-30 15:28:59            167  Twitter for Android
# 47379  2020-10-30 15:28:37            270  Twitter for Android
# 47380  2020-10-30 15:28:14              0  Twitter for Android
#
#                    user_id               user_name  \
# 0      1250294694937914880                    Rumi
# 1                 57059492              Tom Bewick
# 2               1016022678                Lemonade
# ...

# %%
df.columns
# Out:
# Index(['created_at', 'retweet_count', 'source', 'user_id', 'user_name',
#        'user_description', 'user_follower_count', 'user_friends_count',
#        'user_location', 'user_verified', 'user_url', 'tweet',
#        'length_of_tweet'],
#       dtype='str')

# %%
df.shape
# Out:
# (47381, 13)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 47381 entries, 0 to 47380
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   created_at           47381 non-null  str
#  1   retweet_count        47381 non-null  int64
#  2   source               47362 non-null  str
#  3   user_id              47381 non-null  int64
#  4   user_name            47380 non-null  str
#  5   user_description     36510 non-null  str
#  6   user_follower_count  47381 non-null  int64
#  7   user_friends_count   47381 non-null  int64
#  8   user_location        26247 non-null  str
#  9   user_verified        47381 non-null  bool
#  10  user_url             9280 non-null   str
#  11  tweet                47381 non-null  str
#  12  length_of_tweet      47381 non-null  int64
# dtypes: bool(1), int64(5), str(7)
# memory usage: 4.4 MB

# %%
#3
df.sort_values(by="retweet_count",ascending=False)
# Out:
#                 created_at  retweet_count               source  \
# 32860  2020-11-08 05:30:01         614304   Twitter for iPhone
# 33262  2020-11-07 21:52:54         581097  Twitter for Android
# 35111  2020-11-06 14:20:33         381458      Twitter Web App
# 32585  2020-11-08 07:19:02         204348   Twitter for iPhone
# 38044  2020-11-04 18:19:13         192350   Twitter for iPhone
# ...                    ...            ...                  ...
# 47347  2020-10-30 15:48:45              0        WordPress.com
# 47348  2020-10-30 15:48:43              0        WordPress.com
# 47349  2020-10-30 15:48:42              0        WordPress.com
# 47351  2020-10-30 15:46:53              0      Twitter Web App
# 47332  2020-10-30 15:53:51              0  Twitter for Android
#
#                    user_id                                          user_name  \
# 32860  1024658968394625024               \xe3\x81\xb2\xe3\x81\x88\xe3\x81\xa3
# ...

# %%
#4
top = df.iloc[0]

# %%
print("highest retweet record:")
print(top[["source","retweet_count","user_name","tweet","created_at","user_url"]])
# Out:
# highest retweet record:
# source                                         Twitter for Android
# retweet_count                                                  141
# user_name                                                     Rumi
# tweet            RT @Kwa_Mamkhize: I am giving away R5K to 100 ...
# created_at                                     2020-10-31 14:10:28
# user_url                                                       NaN
# Name: 0, dtype: object

# %%
top10 = df.head(10)
total_sum = top10["retweet_count"].sum()
print("top 10 retweet sum is",total_sum)
# Out:
# top 10 retweet sum is 866

# %%
android = df[df["source"] == "Twitter for android"]
print("total tweets from android:",android.shape[0])
print("total retweet from android:",android["retweet_count"].sum())
# Out:
# total tweets from android: 0
# total retweet from android: 0

# %%
max_row = df.loc[df["user_id"].idxmax()]
print("username:",max_row["user_name"])
print("location",max_row["user_location"])
# Out:
# username: Neha Kumari
# location nan

# %%
print(df.columns)
# Out:
# Index(['created_at', 'retweet_count', 'source', 'user_id', 'user_name',
#        'user_description', 'user_follower_count', 'user_friends_count',
#        'user_location', 'user_verified', 'user_url', 'tweet',
#        'length_of_tweet'],
#       dtype='str')

# %%
df.head()
# Out:
#             created_at  retweet_count               source  \
# 0  2020-10-31 14:10:28            141  Twitter for Android
# 1  2020-10-31 14:10:11              1   Twitter for iPhone
# 2  2020-10-31 14:09:48            141      Twitter Web App
# 3  2020-10-31 14:09:41            141  Twitter for Android
# 4  2020-10-31 14:09:22              0  Twitter for Android
#
#                user_id     user_name  \
# 0  1250294694937914880          Rumi
# 1             57059492    Tom Bewick
# 2           1016022678      Lemonade
# 3  1085818329816882944       The Rus
# 4  1227501071490114048  Sakshi Yadav
#
#                                     user_description  user_follower_count  \
# 0                                                NaN                   14
# 1  Proud dad of three & cat, @SussexCCC fan. CEO ...                 2314
# 2  Wisdom is knowing the right path to take, Inte...                  285
# 3                                                NaN                  147
# ...

# %%
# df['followers_friend_ratio'] 
df['user_follower_count'] 
df['user_friends_count']
# Out:
# 0         180
# 1        3002
# 2        1013
# 3         467
# 4          24
#          ...
# 47376     513
# 47377     754
# 47378       2
# 47379    1309
# 47380      45
# Name: user_friends_count, Length: 47381, dtype: int64

# %%
df
# Out:
#                 created_at  retweet_count               source  \
# 0      2020-10-31 14:10:28            141  Twitter for Android
# 1      2020-10-31 14:10:11              1   Twitter for iPhone
# 2      2020-10-31 14:09:48            141      Twitter Web App
# 3      2020-10-31 14:09:41            141  Twitter for Android
# 4      2020-10-31 14:09:22              0  Twitter for Android
# ...                    ...            ...                  ...
# 47376  2020-10-30 15:29:35              0  Twitter for Android
# 47377  2020-10-30 15:29:35           1700  Twitter for Android
# 47378  2020-10-30 15:28:59            167  Twitter for Android
# 47379  2020-10-30 15:28:37            270  Twitter for Android
# 47380  2020-10-30 15:28:14              0  Twitter for Android
#
#                    user_id               user_name  \
# 0      1250294694937914880                    Rumi
# 1                 57059492              Tom Bewick
# 2               1016022678                Lemonade
# ...

# %%
print(df.isnull().sum())
# Out:
# created_at                 0
# retweet_count              0
# source                    19
# user_id                    0
# user_name                  1
# user_description       10871
# user_follower_count        0
# user_friends_count         0
# user_location          21134
# user_verified              0
# user_url               38101
# tweet                      0
# length_of_tweet            0
# dtype: int64

# %%
df['user_description'].fillna('twitter user',inplace=True)
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_11076\252322186.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df['user_description'].fillna('twitter user',inplace=True)
# 0                                             twitter user
# 1        Proud dad of three & cat, @SussexCCC fan. CEO ...
# ...

# %%
df.dropna(axis=1, inplace=True)

# %%
df.insert(2,'is_allow',True)

# %%
df.drop('tweet', axis=1, inplace=True)

# %%
df.head()
# Out:
#             created_at  retweet_count  is_allow               source  \
# 0  2020-10-31 14:10:28            141      True  Twitter for Android
# 1  2020-10-31 14:10:11              1      True   Twitter for iPhone
# 2  2020-10-31 14:09:48            141      True      Twitter Web App
# 3  2020-10-31 14:09:41            141      True  Twitter for Android
# 4  2020-10-31 14:09:22              0      True  Twitter for Android
#
#                user_id     user_name  \
# 0  1250294694937914880          Rumi
# 1             57059492    Tom Bewick
# 2           1016022678      Lemonade
# 3  1085818329816882944       The Rus
# 4  1227501071490114048  Sakshi Yadav
#
#                                     user_description  user_follower_count  \
# 0                                                NaN                   14
# 1  Proud dad of three & cat, @SussexCCC fan. CEO ...                 2314
# 2  Wisdom is knowing the right path to take, Inte...                  285
# ...

# %%
df['created_at'] 
df['created_at'].astype(str)
df[['year','month','day']] = df['created_at'].str.split('-',expand = True)
print(df[['year','month']])
# Out:
#        year month
# 0      2020    10
# 1      2020    10
# 2      2020    10
# 3      2020    10
# 4      2020    10
# ...     ...   ...
# 47376  2020    10
# 47377  2020    10
# 47378  2020    10
# 47379  2020    10
# 47380  2020    10
#
# [47381 rows x 2 columns]
