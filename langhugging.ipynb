# %%
! pip install langchain-huggingface
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: langchain-huggingface in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (1.2.2)
# Requirement already satisfied: huggingface-hub<2.0.0,>=0.33.4 in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from langchain-huggingface) (1.14.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.31 in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from langchain-huggingface) (1.4.0)
# Requirement already satisfied: tokenizers<1.0.0,>=0.19.1 in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from langchain-huggingface) (0.23.1)
# Requirement already satisfied: filelock>=3.10.0 in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (3.29.0)
# Requirement already satisfied: fsspec>=2023.5.0 in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (2026.4.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (1.5.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (6.0.3)
# Requirement already satisfied: tqdm>=4.42.1 in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (4.67.3)
# Requirement already satisfied: typer>=0.20.0 in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (0.24.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (4.15.0)
# Requirement already satisfied: anyio in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (4.12.1)
# Requirement already satisfied: certifi in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (1.0.9)
# Requirement already satisfied: idna in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (3.11)
# Requirement already satisfied: h11>=0.16 in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (0.16.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.14 in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (0.0.15)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (0.8.3)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (2.12.5)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (9.1.4)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (0.15.0)
# Requirement already satisfied: jsonpointer>=1.9 in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (3.0.0)
# Requirement already satisfied: orjson>=3.9.14 in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (2.32.5)
# Requirement already satisfied: xxhash>=3.0.0 in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (3.7.0)
# Requirement already satisfied: zstandard>=0.23.0 in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (2.6.3)
# Requirement already satisfied: colorama in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from tqdm>=4.42.1->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (0.4.6)
# Requirement already satisfied: click>=8.2.1 in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from typer>=0.20.0->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from typer>=0.20.0->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from typer>=0.20.0->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (14.3.3)
# Requirement already satisfied: annotated-doc>=0.0.2 in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from typer>=0.20.0->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from rich>=12.3.0->typer>=0.20.0->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from rich>=12.3.0->typer>=0.20.0->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer>=0.20.0->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (0.1.2)
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
! pip install streamlit
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: streamlit in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (1.55.0)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<7,>=4.0 in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<8,>=5.5 in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from streamlit) (7.0.4)
# Requirement already satisfied: click<9,>=7.0 in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from streamlit) (8.3.1)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from streamlit) (3.1.46)
# Requirement already satisfied: numpy<3,>=1.23 in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from streamlit) (2.4.2)
# Requirement already satisfied: packaging>=20 in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from streamlit) (26.0)
# Requirement already satisfied: pandas<3,>=1.4.0 in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from streamlit) (2.3.3)
# Requirement already satisfied: pillow<13,>=7.1.0 in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from streamlit) (12.1.1)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: protobuf<7,>=3.20 in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from streamlit) (6.33.5)
# Requirement already satisfied: pyarrow>=7.0 in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from streamlit) (23.0.1)
# Requirement already satisfied: requests<3,>=2.27 in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from streamlit) (2.32.5)
# Requirement already satisfied: tenacity<10,>=8.1.0 in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from streamlit) (9.1.4)
# Requirement already satisfied: toml<2,>=0.10.1 in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from streamlit) (6.5.4)
# Requirement already satisfied: typing-extensions<5,>=4.10.0 in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from streamlit) (4.15.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: jinja2 in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (4.26.0)
# Requirement already satisfied: narwhals>=1.27.1 in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2.17.0)
# Requirement already satisfied: colorama in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from pandas<3,>=1.4.0->streamlit) (2026.1.post1)
# Requirement already satisfied: tzdata>=2022.7 in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from requests<3,>=2.27->streamlit) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from requests<3,>=2.27->streamlit) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from requests<3,>=2.27->streamlit) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from requests<3,>=2.27->streamlit) (2026.1.4)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.30.0)
# Requirement already satisfied: six>=1.5 in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install python-dotenv
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: python-dotenv in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (1.2.2)
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install huggingface_hub
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: huggingface_hub in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (1.14.0)
# Requirement already satisfied: filelock>=3.10.0 in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from huggingface_hub) (3.29.0)
# Requirement already satisfied: fsspec>=2023.5.0 in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from huggingface_hub) (2026.4.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from huggingface_hub) (1.5.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from huggingface_hub) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from huggingface_hub) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from huggingface_hub) (6.0.3)
# Requirement already satisfied: tqdm>=4.42.1 in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from huggingface_hub) (4.67.3)
# Requirement already satisfied: typer>=0.20.0 in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from huggingface_hub) (0.24.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from huggingface_hub) (4.15.0)
# Requirement already satisfied: anyio in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from httpx<1,>=0.23.0->huggingface_hub) (4.12.1)
# Requirement already satisfied: certifi in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from httpx<1,>=0.23.0->huggingface_hub) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from httpx<1,>=0.23.0->huggingface_hub) (1.0.9)
# Requirement already satisfied: idna in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from httpx<1,>=0.23.0->huggingface_hub) (3.11)
# Requirement already satisfied: h11>=0.16 in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface_hub) (0.16.0)
# Requirement already satisfied: colorama in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from tqdm>=4.42.1->huggingface_hub) (0.4.6)
# Requirement already satisfied: click>=8.2.1 in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from typer>=0.20.0->huggingface_hub) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from typer>=0.20.0->huggingface_hub) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from typer>=0.20.0->huggingface_hub) (14.3.3)
# Requirement already satisfied: annotated-doc>=0.0.2 in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from typer>=0.20.0->huggingface_hub) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from rich>=12.3.0->typer>=0.20.0->huggingface_hub) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from rich>=12.3.0->typer>=0.20.0->huggingface_hub) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in C:\Users\dell\AppData\Roaming\Python\Python314\site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer>=0.20.0->huggingface_hub) (0.1.2)
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain_huggingface import ChatHuggingFace, HuggingFaceEndpoint

# %%
from dotenv import load_dotenv
import streamlit as st

# %%
load_dotenv()
st.header("Hugging Face ChatBot")
# Out:
# 2026-05-13 21:11:59.432 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-13 21:11:59.805
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\dell\AppData\Roaming\Python\Python314\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2026-05-13 21:11:59.807 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-13 21:11:59.809 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
llm = HuggingFaceEndpoint(
    repo_id="meta-ollama/Llama-3.3-7OB-Instruct:sambanova",
    task="text-generation"
)

# %%
model = ChatHuggingFace(llm=llm)
input_text=st.text_input("Enter Your Question here")
if st.button("Ask Question"):
    result=model.invoke(input_text)
    st.write(result.content)
# Out:
# 2026-05-13 21:19:52.264 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-13 21:19:52.266 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-13 21:19:52.267 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-13 21:19:52.268 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-13 21:19:52.269 Session state does not function when running a script without `streamlit run`
# 2026-05-13 21:19:52.271 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-13 21:19:52.272 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-13 21:19:52.273 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-13 21:19:52.274 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-13 21:19:52.276 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-13 21:19:52.277 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-13 21:19:52.278 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-13 21:19:52.279 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-13 21:19:52.281 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
from langchain_community.document_loaders import TextLoader
loader = TextLoader("text.txt.pdf")
# Out:
# C:\Users\dell\AppData\Roaming\Python\Python314\site-packages\langchain_core\utils\pydantic.py:41: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1 import BaseModel as BaseModelV1

# %%
text_doc= loader.load()
text_doc
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python314\site-packages\langchain_community\document_loaders\text.py:43, in TextLoader.lazy_load(self)
#      42     with open(self.file_path, encoding=self.encoding) as f:
# ---> 43         text = f.read()
#      44 except UnicodeDecodeError as e:
#
# File C:\Program Files\Python314\Lib\encodings\cp1252.py:23, in IncrementalDecoder.decode(self, input, final)
#      22 def decode(self, input, final=False):
# ---> 23     return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x81 in position 84: character maps to <undefined>
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 text_doc= loader.load()
#       2 text_doc
#
# File ~\AppData\Roaming\Python\Python314\site-packages\langchain_core\document_loaders\base.py:43, in BaseLoader.load(self)
#      37 def load(self) -> list[Document]:
#      38     """Load data into `Document` objects.
#      39
#      40     Returns:
#      41         The documents.
#      42     """
# ---> 43     return list(self.lazy_load())
#
# File ~\AppData\Roaming\Python\Python314\site-packages\langchain_community\document_loaders\text.py:56, in TextLoader.lazy_load(self)
#      54                 continue
#      55     else:
# ---> 56         raise RuntimeError(f"Error loading {self.file_path}") from e
#      57 except Exception as e:
#      58     raise RuntimeError(f"Error loading {self.file_path}") from e
#
# RuntimeError: Error loading text.txt.pdf
