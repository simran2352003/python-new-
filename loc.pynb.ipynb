# %%
data.loc[['x','w']]
# Out:
# x    100
# w    400
# dtype: int64

# %%
data.iloc[-1]
# Out:
# np.int64(400)

# %%
data.loc['y':'z']
# Out:
# y    200
# z    300
# dtype: int64

# %%
data.iloc[1]
# Out:
# np.int64(200)

# %%
import pandas as pd
data = pd.Series([100,200,300,400],
index = ['x','y','z','w'])

# %%
data.loc['y']
# Out:
# np.int64(200)

# %%
data.iloc[1]
# Out:
# np.int64(200)

# %%
data.loc[['x','w']]
# Out:
# x    100
# w    400
# dtype: int64

# %%
data.iloc[-1]
# Out:
# np.int64(400)

# %%
data.loc['y':'z']
# Out:
# y    200
# z    300
# dtype: int64
