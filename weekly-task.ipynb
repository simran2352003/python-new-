# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
X = np.array([30,40,50,60,70,80,90])
y = np.array([0,0,0,1,1,1,1])

# %%
X = X.reshape(-1,1)

# %%
X = X / 100.0

# %%
#section B

# %%
model = keras.Sequential([
layers.Dense(8,activation='relu',input_shape=(1,)),
layers.Dense(4,activation='relu'),
layers.Dense(1,activation='sigmoid')])

# %%
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# %%
model.fit(X,y,epochs=10)
# Out:
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5714 - loss: 0.6887
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.5714 - loss: 0.6884
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.5714 - loss: 0.6882
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.5714 - loss: 0.6880
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.5714 - loss: 0.6877
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.5714 - loss: 0.6875
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.5714 - loss: 0.6872
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.5714 - loss: 0.6870
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.5714 - loss: 0.6867
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.5714 - loss: 0.6865

# %%
layers.Dense(8, activation='relu')
# Out:
# <Dense name=dense_13, built=False>

# %%
layers.Dense(8, activation='tanh')
# Out:
# <Dense name=dense_14, built=False>

# %%
# 3 training and testing

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
from tensorflow.keras.datasets import boston_housing

# %%
data = np.load(C:\Users\dell\Downloads\boston_housing (2).npz)
# Out:
#   File "/tmp/ipykernel_55/2824473143.py", line 1
#     data = np.load(C:\Users\dell\Downloads\boston_housing (2).npz)
#                     ^
# SyntaxError: invalid syntax

# %%
X_train = X_train / X_train.max()
X_test  = X_test / X_test.max()
