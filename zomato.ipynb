# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('py.ipynb/archive (1).csv')
df.head()
# Out:
#   Cell In[13], line 1
#     df = pd.read_csv('C:\Users\dell\Downloads\complete-zomato-dataset-eda.ipynb')
#                      ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape
